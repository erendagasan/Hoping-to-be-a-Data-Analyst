# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1,2,3,4,5,6,7,8]
y = [1,4,9,16,25,36,49,64]

# %%
plt.xlabel("fuck")
plt.ylabel("Fuck")
plt.title("Fuck")
plt.plot(x,y, ".")

# %% [markdown]
#  Scatter Plot

# %%
x = 20 * np.random.randn(1000) + 100
y = x + (10 * np.random.randn(1000) + 50)

# %%
plt.scatter(x,y, color = "red")

# %% [markdown]
# Bar Chart

# %%
x = ["Covid-19", "Healthy", "Symptomatic"]
y = [1010, 8562, 1843]

# %%
plt.bar(x,y, color ="black")
plt.plot(x,y, color = "red")

# %% [markdown]
# Histogram

# %%
import seaborn as sns

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.histplot(data=penguins, x="flipper_length_mm")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# Pie Chart

# %%
etiketler = ["elma", "muz", "kiraz", "erik"]
sayi = [35,25,25,15]

plt.pie(sayi, labels = etiketler, autopct = "%1.1f%%")
plt.show()

# %% [markdown]
# Heatmap

# %%
data = np.random.randn(10,12)
data

# %%
sns.heatmap(data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Box Plot

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x = tips["total_bill"])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
x = [1,2,3,4,5,6,7,8]
y = [1,4,9,16,25,36,49,64]

x2 = [1,2,3,4,5,6,7,8]
y2 = [1,8,27,64,125,216,343,512]

# %%
plt.plot(x,y, label = "X kare degerleri")
plt.plot(x2,y2, color = "red", label = "X küp degerleri")

plt.title("Line Plot")
plt.xlabel("X Ekseni")
plt.ylabel("Y Ekseni")

plt.legend()
plt.grid()
plt.show()

# %%
fig = plt.figure(figsize = (18,5), )

first_plot = fig.add_subplot(1,3,1)
first_plot.plot(x,y, label = "X kare degerleri")
first_plot.set_title("Fuck")
first_plot.legend()

second_plot = fig.add_subplot(1,3,2)
second_plot.scatter(x,y, color = "red")
second_plot.set_title("Fuck")


third_plot = fig.add_subplot(1,3,3)
third_plot.bar(x,y, color = "grey")
third_plot.set_title("Fuck")

plt.show()

# %% [markdown]
# #PROJE İLE DATA VISUALIZATION

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("planets")

# %%
df = data.copy()

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.tail()
# Out:
#        method  number  orbital_period  mass  distance  year
# 1030  Transit       1        3.941507   NaN     172.0  2006
# 1031  Transit       1        2.615864   NaN     148.0  2007
# 1032  Transit       1        3.191524   NaN     174.0  2007
# 1033  Transit       1        4.125083   NaN     293.0  2008
# 1034  Transit       1        4.187757   NaN     260.0  2008

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
df.dtypes
# Out:
# method             object
# number              int64
# orbital_period    float64
# mass              float64
# distance          float64
# year                int64
# dtype: object

# %%
df["method"] = pd.Categorical(df.method)

# %%
df.dtypes
# Out:
# method            category
# number               int64
# orbital_period     float64
# mass               float64
# distance           float64
# year                 int64
# dtype: object

# %%
df.shape
# Out:
# (1035, 6)

# %%
df.columns
# Out:
# Index(['method', 'number', 'orbital_period', 'mass', 'distance', 'year'], dtype='object')

# %%
df.describe().T
# Out:
#                  count         mean           std          min         25%  \
# number          1035.0     1.785507      1.240976     1.000000     1.00000
# orbital_period   992.0  2002.917596  26014.728304     0.090706     5.44254
# mass             513.0     2.638161      3.818617     0.003600     0.22900
# distance         808.0   264.069282    733.116493     1.350000    32.56000
# year            1035.0  2009.070531      3.972567  1989.000000  2007.00000
#
#                       50%       75%       max
# number             1.0000     2.000       7.0
# orbital_period    39.9795   526.005  730000.0
# mass               1.2600     3.040      25.0
# distance          55.2500   178.500    8500.0
# year            2010.0000  2012.000    2014.0

# %%
df.describe(include = ["category"]).T
# Out:
#        count unique              top freq
# method  1035     10  Radial Velocity  553

# %%
df.isna().values.any() #null var mı
# Out:
# True

# %%
df.isna().sum() #kac null var?
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
df["mass"].fillna(df.mass.mean(), inplace = True)

# %%
df.isna().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass                0
# distance          227
# year                0
# dtype: int64

# %%
df.fillna(df.mean(), inplace = True) #eksik veriler gitti :)
# Out:
# C:\Users\erend\AppData\Local\Temp\ipykernel_7104\3744956975.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(), inplace = True) #eksik veriler gitti :)

# %%
df.isna().sum()
# Out:
# method            0
# number            0
# orbital_period    0
# mass              0
# distance          0
# year              0
# dtype: int64

# %%
categorical_df = df.select_dtypes(include = "category")

# %%
categorical_df.tail()
# Out:
#        method
# 1030  Transit
# 1031  Transit
# 1032  Transit
# 1033  Transit
# 1034  Transit

# %%
categorical_df.method.unique()
# Out:
# ['Radial Velocity', 'Imaging', 'Eclipse Timing Variations', 'Transit', 'Astrometry', 'Transit Timing Variations', 'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing', 'Pulsation Timing Variations']
# Categories (10, object): ['Astrometry', 'Eclipse Timing Variations', 'Imaging', 'Microlensing', ..., 'Pulsation Timing Variations', 'Radial Velocity', 'Transit', 'Transit Timing Variations']

# %%
categorical_df.method.nunique()
# Out:
# 10

# %%
categorical_df.method.value_counts()
# Out:
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# Name: method, dtype: int64

# %%
df["method"].value_counts().plot.bar() #bar plot ile gosterim
# Out:
# <AxesSubplot:>

# %%
df["method"].value_counts().plot.barh() #yatay bar chart
# Out:
# <AxesSubplot:>

# %%
df["method"].value_counts().sort_values().plot.barh()
# Out:
# <AxesSubplot:>

# %%
diamonds = sns.load_dataset("diamonds")
data = diamonds
df = data.copy()

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df.describe().T
# Out:
#          count         mean          std    min     25%      50%      75%  \
# carat  53940.0     0.797940     0.474011    0.2    0.40     0.70     1.04
# depth  53940.0    61.749405     1.432621   43.0   61.00    61.80    62.50
# table  53940.0    57.457184     2.234491   43.0   56.00    57.00    59.00
# price  53940.0  3932.799722  3989.439738  326.0  950.00  2401.00  5324.25
# x      53940.0     5.731157     1.121761    0.0    4.71     5.70     6.54
# y      53940.0     5.734526     1.142135    0.0    4.72     5.71     6.54
# z      53940.0     3.538734     0.705699    0.0    2.91     3.53     4.04
#
#             max
# carat      5.01
# depth     79.00
# table     95.00
# price  18823.00
# x         10.74
# y         58.90
# z         31.80

# %%
df.isna().any() #herhangi bir null deger var mı buna baktık
# Out:
# carat      False
# cut        False
# color      False
# clarity    False
# depth      False
# table      False
# price      False
# x          False
# y          False
# z          False
# dtype: bool

# %%
df["cut"].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
df["color"].value_counts()
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
df["color"].value_counts().sort_values().plot.barh(color = 
                                                   "grey")
# Out:
# <AxesSubplot:>

# %%
from pandas.api.types import CategoricalDtype

# %%
df.cut = df.cut.astype(CategoricalDtype (ordered = True))

# %%
df.cut.head()
# Out:
# 0      Ideal
# 1    Premium
# 2       Good
# 3    Premium
# 4       Good
# Name: cut, dtype: category
# Categories (5, object): ['Ideal' < 'Premium' < 'Very Good' < 'Good' < 'Fair']

# %%
df["cut"].value_counts().plot.barh().set_title("Jewelery Cuts")
# Out:
# Text(0.5, 1.0, 'Jewelery Cuts')
