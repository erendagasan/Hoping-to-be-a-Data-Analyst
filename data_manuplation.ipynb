# %% [raw]
# import numpy as np
# a = np.array([1,2,3,4])
# b = np.array([2,3,4,5])
# c = np.array([6,7,8,9])
# a*b*c

# %% [raw]
# np.zeros(10, dtype = "int")
# #sıfırlardan 10 elemanlı bir array olustur.

# %% [raw]
# np.ones((3,5), dtype = ("int"))
# #3`e 5lik bir matrisi 1 ile doldur.

# %% [raw]
# np.full((3,5), 4, dtype = "int")
# #3`e 5lik bir matrisi 4 ile doldur.

# %% [raw]
# np.arange(0,30,3)
# #0-30 arasında 3`er atlayarak sayıları yaz:***

# %% [raw]
# np.linspace(0,1,10)
# # 0-1 arasında 10 adet sayı olustur.

# %% [raw]
# np.random.normal(10,4, (3,4))
# #ortalaması 10, standart sapması 4 olacak sekilde array olustu*

# %% [raw]
# a = np.random.randint(0,10, (3,3))
# a
# #int değerlerden rastgele olusturulmus (0-10 arası) 3,3 matris*

# %% [raw]
# a.ndim
# #boyut sayısı(dimension)

# %% [raw]
# a.shape
# #boyut bilgisi

# %% [raw]
# a.size
# #toplam eleman sayisi

# %% [raw]
# a.dtype
# #array veri tipi

# %% [raw]
# b = np.random.randint(0,10, (2,2))
# b
# #int değerlerden rastgele olusturulmus (0-10 arası) 2,2 matris*

# %% [raw]
# b.size

# %% [raw]
# b.shape

# %% [raw]
# b.dtype

# %% [raw]
# b.ndim

# %% [raw]
# #RESHAPING ORNEKLER
# j = np.random.randint(0,10, size = 9)
# #0-10 arası int olusturma
# j

# %% [raw]
# j.reshape((3,3))

# %% [raw]
# j.reshape((1,9))
# #burada tek boyutlu bir matris olusturduk.
# #matrsi olmasını istedik ancak tek boyut bilgileirni korumasını
# #da istedik

# %% [raw]
# j.ndim #reshape edilmis son j arrayinin dim sayısı

# %% [raw]
# **ARRAY BİRLESTİRME (Concatenation)**

# %% [raw]
# import numpy as np

# %% [raw]
# x = np.array([1,2,3,4])
# y = np.array([4,5,6,8])
# z = np.array([6,7,8,9])

# %% [raw]
# np.concatenate([x,y,z])
# #dimension gozetmeksizin array birlestirme kodu.

# %% [raw]
# x = np.array([1,2,3,4])
# y = np.array([4,5,6,8])
# z = np.array([6,7,8,9])
#
# np.concatenate([[x],
#                 [y],
#                 [z]])
#
# #alt alta matris seklinde birlestirme

# %% [raw]
# x = np.array([1,2,3,4])
# y = np.array([4,5,6,8])
# z = np.array([6,7,8,9])
#
# np.concatenate([[x],
#                 [y],
#                 [z]], axis = 1)
# #axis deger ise satır olarak birlestirmeye yarar
# #default sıfırdır, 1 yaparsan satır halinde birlestirir.

# %% [raw]
# **ARRAY AYIRMA (SPLITTING)**

# %% [raw]
# import numpy as np

# %% [raw]
# x = np.array([1,2,3,99,99,3,2,1])

# %% [raw]
# np.split(x, [3,5])
#
# #array böler. x arrayini önce 3`e kadar sonra 3`ten 5`e kadar
# #böl komutudur.

# %% [raw]
# #bolerek aldıgımız arrayleri nasıl kullanıcaz
# a,b,c = np.split(x, [3,5])

# %% [raw]
# a #bolunen arrayler

# %% [raw]
# b #bolunen arrayler

# %% [raw]
# c #bolunen arrayler

# %% [raw]
# #iki boyutlu bolme islemi, 2. satırdan sonraki kısmı dikey ekle
# m = np.arange(16).reshape(4,4)
# m

# %% [raw]
# np.vsplit(m, [2])
# #yatay eksende 2ye boldu

# %% [raw]
# np.hsplit(m, [2])
# #dikey eksende 2ye boldu

# %% [raw]
# #bolunen parcaları kullanma
# ust, alt = np.vsplit(m ,[2])
# ust

# %% [raw]
# alt

# %% [raw]
# **SIRALAMA (SORTING)**

# %% [raw]
# import numpy as np

# %% [raw]
# k = np.array([4,5,3,9])
# k

# %% [raw]
# np.sort(k)
# k
# #array yapısını bozmadan fonk icine yazilarak sortlanır
# #np.sort(k) fonksiyonu yeni bi degere atanarak kullanılır
# #fonk asıl k fonksiyonunda herhangi bir degisiklik yapmadı

# %% [raw]
# k.sort()
# k
# #direkt olarak arrayi degistirdi, array bundan sonra sorted
# #hali ile kullanılacak

# %% [raw]
# #iki boyutlu array sıralama
# a = np.random.randint(0,10 ,(3,3))
# a

# %% [raw]
# a.sort()
# a
# #satıralrı kendi icerisinde kucukten buyuge sıraladı

# %% [raw]
# np.sort(a, axis=1)
# #axis 1 yazılmasa da olur.
# #satıralrı kendi icerisinde kucukten buyuge sıraladı

# %% [raw]
# np.sort(a, axis = 0)
# #sütunları kendi icerisinde kucukten buyuge sıraladı

# %% [raw]
# **INDEX İLE ELEMANLARA ERİSMEK**

# %% [raw]
# import numpy as np

# %% [raw]
# a = np.random.randint(0,10, 10)
# print(a)
# a[0] = 100 # birinci eleman degistirildi
# print(a) #seklinde bir yazim ile elemana erisildi
# print(a[-1])#elemana tersten erisildi yani son eleman

# %% [raw]
# m = np.random.randint(0,10, (2,2))
# print(m)
# m[1,1] = 2.2 # 1,1`deki eleman degistirildi
# print(m) #seklinde bir yazim ile elemana erisildi
# print(m[1,1])#elemana tersten erisildi yani son eleman
#
# #float tipinde bir sayi eklenmek istenirse, int seklinde ekler

# %% [raw]
# **SLICING İLE ELEMANLARA ERİSMEK**

# %% [raw]
# import numpy as np

# %% [raw]
# a = np.arange(0,20, (2))
# a

# %% [raw]
# a[0:3] #0-3 arasi

# %% [raw]
# a[:6] #ilk elemandan sona kadar

# %% [raw]
# a[3:] #3. elemandan basla sonuna kadar git

# %% [raw]
# a[0::3] #sıfırıncı  elemandan baslayarak 3er 3er art

# %% [raw]
# m = np.random.randint(0,10, (5,5))
# m

# %% [raw]
#  m[:,1]
# #iki nokta tum satırları sec demektir.
# #1 ise 1. indexte yer alan sutunu temsil eder.

# %% [raw]
# m[0,:]
# #ilk satırı verir

# %% [raw]
# m[0:2, 0:3]
# #0`dan 2`ye kadar satırları al,
# #0dan 3e kadar da sutunları al.

# %% [raw]
# **ALT KUME UZERİNDE İSLEM YAPMAK**

# %% [raw]
# import numpy as np

# %% [raw]
# a = np.random.randint(0,10, (5,5))

# %% [raw]
# a

# %% [raw]
# alt_a = a[0:3, 0:2] #array alt kumesi secildi
# alt_a

# %% [raw]
# alt_a[0,0] = 99999 # array alt kumesinde yapilan degisiklik
# alt_a              # arrayi de etkiledi

# %% [raw]
# a #alt kume degisikliginden etkilenmis array

# %% [raw]
# #alt kume arrayin ana arrayi etkilememsi icin copy metodu
# #kullanılır

# %% [raw]
# b = np.random.randint(0,10, (5,5))
# b

# %% [raw]
# alt_b = b[0:3, 0:2].copy() #ana array etkilenmedi
# alt_b

# %% [raw]
# alt_b[0,0] = 999 #alt_b copy uzerinde degisilik yapildi
# alt_b

# %% [raw]
# b #etkilenmemis array gorulebilir

# %% [raw]
# **Fancy Index ile Elemanlara Erismek**

# %% [raw]
# import numpy as np
#
# #fancy index cok onemli******
# #cok sık kullanılıyor.
# #pandas da da lazım olacak******
# #fancy index array icerisindeki cok sayidaki elemanı
# #sorgulamaya yaramaktadır
# #fonksiyon veya döngu cıktılarını liste seklinde
# #kaydedip sonrasında asıl array uzerinden cagırılmaya denir

# %% [raw]
# v = np.arange(0,20,2)
# v

# %% [raw]
# getir = [1,3,5]

# %% [raw]
# v[getir]
# #fancy index budur.

# %% [raw]
# #iki boyutlu fancy index uygulaması

# %% [raw]
# m = np.random.randint(0,10, (5,5))
# m

# %% [raw]
# satir = np.array([0,1,2])
# sutun = np.array([2,3,4])

# %% [raw]
# m[satir, sutun]

# %% [raw]
# #basit index ile fancy index
# m

# %% [raw]
# m[0, [1,2]]

# %% [raw]
# #slice ile fancy index
# m[0:, [1,2]]

# %% [raw]
# **Kosullu Eleman İslemleri**

# %% [raw]
# import numpy as np
#
# #fancy index kullanılır.

# %% [raw]
# v = np.arange(0,10)
# v

# %% [raw]
# v < 5 #sadece true false degeri gosterir elemanlara erisim yok

# %% [raw]
# v[v < 5]
# #fancy index kullanıldı. array icerisinden degerler dondu.
# #array icerisine ilgili sartlar girildi, for gibi cıktı verdi

# %% [raw]
# v[v != 3] #3 dısındakileri getir

# %% [raw]
# #NP ARRAYLER İLE DİREKT OLARAK İSLEMLER YAPILABİLİR.
# v**2 #gibi

# %% [raw]
# **NUMPY ARRAYLER UZERİNDE MAT İSLEMLERİ**

# %% [raw]
# import numpy as np

# %% [raw]
# v = np.arange(0,10)
# v

# %% [raw]
# v - 1

# %% [raw]
# v*5

# %% [raw]
# v/5

# %% [raw]
# v*5/10-1

# %% [raw]
# #BİZ SEMBOLLERİ KOYDUGUMUZDA ASLINDA FONKSİYON CALISMAKTA

# %% [raw]
# #ORNEK
# np.subtract(v, 1) #V ARRAYINDEN 1 CIKAR DEMEK

# %% [raw]
# np.add(v, 1) #V ARRAYE 1 EKLE

# %% [raw]
# np.multiply(v, 8)

# %% [raw]
# np.divide(v, 5)

# %% [raw]
# np.power(v,2)

# %% [raw]
# np.mod(v,2)

# %% [raw]
# np.absolute(np.array([-3])) #MUTLAK DEGER

# %% [raw]
# np.sin(360)

# %% [raw]
# np.cos(180)

# %% [raw]
# np.log([1,2,3])

# %% [raw]
# np.log10([1,2,3])

# %% [raw]
# #NUMPY GENEL DOKUMANTASYONA ULASTIK
# ?np

# %% [raw]
# #CHEATSHEET
# #herhangi bir kutuphane hakkında detaylı bilgi icin
# #googlea kutuphane adı, sonuna da cheatsheet yazılır

# %% [raw]
# **NUMPY İLE İKİ BİLİNMEYENLİ DENKLEM COZUMU**

# %% [raw]
# import numpy as np
#
# # 5*x0 + x1 = 12
# # x0 +3*x1 = 10
#
# #iki bilinmeyenli denklemini cozelim

# %% [raw]
# a = np.array([[5,1], [1,3]])
# #once denklemin bilinmeyenlerininin katsayilarını
# #array icerisinde ifade ettik
#
# b = np.array([12,10])
#
# #denklemlerin sonucunu da farklı bir array icerisinde sakladık

# %% [raw]
# #linalg numpy icerisinde lineer cebir islemleri yapmak icin
# #olusturulmus bir kutuphanedir.
# x = np.linalg.solve(a, b)
# x

# %% [raw]
# **PANDAS GİRİS**

# %% [raw]
# #PANDAS NUMPYDAN FARKLI OLARAK ICERISINDA FARKLI DTYPELAR
# #BULUNAN VERİLER İLE DE CALISABİLMEKTEDİR
#
# #PANDAS PANEL VERİ UZERİNE GELİSTİRİLMİSTİR.
# #PANEL VERİ, KESİT VERİ VE ZAMAN BİLGİSİNİN BİR ARADA BULUNDUGU
# #VERİ TURUDUR.
# #ZAMAN INDEXI DAHA FAZLA ONEMSENİR.
# #EKONOMETRİK VE FİNANSAL CALISMALAR İCİN DOGMUSTUR.
# #R DATAFRAME YAPISI UZERİNDE CALISABİLME İMKANI SUNMUSTUR.

# %% [raw]
# **PANDAS SERİSİ OLUSTURMAK**

# %% [raw]
# import pandas as pd

# %% [raw]
# seri = pd.Series([30,2,3,4,5]) #pandas serisi, ilk sutun index!
# seri

# %% [raw]
# type(seri)

# %% [raw]
# seri.axes #serinin baslangıc ve bitis eleman sayisini gosterir

# %% [raw]
# seri.dtype #datatype

# %% [raw]
# seri.size #kac eleman var

# %% [raw]
# seri.ndim #boyut sayisi

# %% [raw]
# seri.values #olusturulan serideki verileri array formunda verir

# %% [raw]
# seri.head(3) #ilk 3 degeri goster demek

# %% [raw]
# seri.tail(3) #sondan 3 elemani goster demek

# %% [raw]
# pd.Series([99,22,332,94,5])

# %% [raw]
# #index ismi numarası degistirme
# pd.Series([99,22,332,94,5], index = [1,6,87,9,4])

# %% [raw]
# seri=pd.Series([99,22,332,94,5], index = ["a","b","c","d","e"])
# seri

# %% [raw]
# seri["a"] #seri icersinden a`indexine karsılık gelen degere bak

# %% [raw]
# seri["a":"c"]

# %% [raw]
# #sozluk uzerinden liste olusturmak

# %% [raw]
# sozluk = {"reg":10, "log":20, "cart":12}

# %% [raw]
# seri = pd.Series(sozluk)
# seri

# %% [raw]
# seri["reg": "log"]

# %% [raw]
# #iki seriyi birlestirerek seri olusturma
#
# pd.concat([seri ,seri])

# %% [raw]
# **ELEMAN İSLEMLERİ**

# %% [raw]
# import numpy as np
# import pandas as pd

# %% [raw]
# a = np.array([10,20,30,40,50])
# seri = pd.Series(a)
# seri

# %% [raw]
# seri[0]

# %% [raw]
# seri[0:3]

# %% [raw]
# seri = pd.Series([10,20,30,40,50],
#                  index = ["a","b","c","d","e"])

# %% [raw]
# seri

# %% [raw]
# seri.index

# %% [raw]
# seri.keys

# %% [raw]
# list(seri.items())
# #tum degerleri bir liste icerisinde toplayabilmeyi saglar

# %% [raw]
# seri.values

# %% [raw]
# #eleman sorgulama

# %% [raw]
# "reg" in seri #"reg" itemi seri icerisinde yer aliyor mu?

# %% [raw]
# "a" in seri

# %% [raw]
# #fancy eleman ile eleman secimi
#
# seri[["a", "b"]]

# %% [raw]
# seri["a"] = 99999
# seri

# %% [raw]
# seri["a":"d"]

# %% [raw]
# **Pandas DataFrame Olusturma**

# %% [raw]
# import pandas as pd
# import numpy as np

# %% [raw]
# a = [11,22,33,44,55]

# %% [raw]
# #tek degiskenli bir data frame olusturma
# pd.DataFrame(a, index =["a","b","c","d","e"],
#              columns = ["degisken_ismi"] )

# %% [raw]
# m = np.arange(1,10).reshape(3,3)
# m

# %% [raw]
# pd.DataFrame(m, columns = ["var1","var2", "var3"],
#              index = [1,2,3])

# %% [raw]
# #df isimlendirme
# df = pd.DataFrame(m, columns = ["var1","var2", "var3"],
#              index = [1,2,3])
# df.head()

# %% [raw]
# df.columns

# %% [raw]
# df.columns = ["eren", "pelin", "gokce"]
# df

# %% [raw]
# df.axes

# %% [raw]
# df.shape

# %% [raw]
# df.ndim

# %% [raw]
# df.size

# %% [raw]
# df.values #dataframe numpy arrayine donusup array olarak
# #listelendi

# %% [raw]
# import numpy as np
# import pandas as pd
# s1 = np.random.randint(10, size=5)
# s2 = np.random.randint(10, size=5)
# s3 = np.random.randint(10, size=5)
# s1

# %% [raw]
# sozluk = {"var1" : s1, "var2": s2, "var3": s3}

# %% [raw]
# dataf = pd.DataFrame(sozluk)
# dataf

# %% [raw]
# dataf.index=["a","b","c","d","e"]
# dataf

# %% [raw]
# dataf["c":"e"]

# %% [raw]
# #YA DA ARGÜMAN KULLANILIR
# dataf.drop("a", inplace = True)
# dataf

# %% [raw]
# #fancy ile
# l = ["c","e"]
# dataf.drop(l, axis=0)

# %% [raw]
# "var1" in dataf

# %% [raw]
# m=["var1", "var2", "var5"]
# for i in m:
#     print(i in dataf)

# %% [raw]
# dataf["var4"] = dataf["var1"]*dataf["var2"]

# %% [raw]
# dataf

# %% [raw]
# #degisken silmek
# dataf.drop("var4", axis=1, inplace=True)
# dataf

# %% [raw]
# liste = ["var2","var3"]
# dataf.drop(liste, axis=1, inplace=True)
# dataf

# %% [raw]
# **GOZLEM VE DEGİSKEN SECİMİ**

# %% [raw]
# import numpy as np
# import pandas as pd
# liste = np.random.randint(1,30 , size = (10,3))
# df = pd.DataFrame(liste, columns =["var1","var2","var3"])
# df

# %% [raw]
# #loc: secim yapmak icin kullanılır.
# df.loc[0:3]

# %% [raw]
# #alısık olunan index mantıgı ile secim yapilir
# df.iloc[0:3]

# %% [raw]
# df.iloc[1,1]

# %% [raw]
# df.iloc[:3,:2]

# %% [raw]
# df.loc[0:3, "var3"]
# #iloc burada hata verir.
# #iloc ile degisken birimi kullanilamaz.
# #sadece sayi kullanıp secim yapilacaksa iloc kullan

# %% [raw]
# df.loc[2]["var3"]

# %% [raw]
# **KOŞULLU ELEMAN İŞLEMLERİ**

# %% [raw]
# import numpy as np
# import pandas as pd
#
# m = np.random.randint(1,30, size=(10,3))
# df = pd.DataFrame(m, columns=["var1","var2","var3"])
# df

# %% [raw]
# df["var1"]

# %% [raw]
# df.loc[0:,"var1"]

# %% [raw]
# df.var1

# %% [raw]
# df[df.var1 > 15]["var1"]

# %% [raw]
# df[(df.var1 > 15) & (df.var3 < 5)]["var2"]

# %% [raw]
# df.loc[(df.var1 > 15), ["var1","var2"]]

# %% [raw]
# **BİRLESTİRME JOİN İSLEMLERİ**

# %% [raw]
# import numpy as np
# import pandas as pd

# %% [raw]
# p = np.random.randint(1,30, size=(5,3))
# df1 = pd.DataFrame(p, columns=["var1","var2","var3"])
# df1

# %% [raw]
# df2 = df1 + 99
# df2

# %% [raw]
# pd.concat([df1,df2]) #indexlerde sikinti cikti

# %% [raw]
# pd.concat([df1,df2], ignore_index = True)
# #index problemi ortadan kalkti

# %% [raw]
# df1.columns

# %% [raw]
# df2.columns =["var1","var2","deg3"]
# df2

# %% [raw]
# pd.concat([df1,df2], ignore_index = True)
# #degisken isimleri farkli oldugu icin problem cikti
# #birlesmedi

# %% [raw]
# pd.concat([df1, df2], join = "inner", ignore_index = True)
# #KESİSİMLERE GORE BİRLESTİREREK SORUNLU DEGİSKENLER ORTADAN
# #KALDIRILDI

# %% [raw]
# pd.concat([df1, df2], join = "inner", ignore_index = True)

# %% [raw]
# pd.concat([df1,df2],
#           ignore_index = True).reindex(df1.columns,
#                                               axis=1)

# %% [raw]
# **İLERİ BİRLESTİRME İSLEMLERİ**

# %% [raw]
# import numpy as np
# import pandas as pd
# df1 = pd.DataFrame({"calisanlar": ["ali", "veli",
#                                    "ayse","fatma"],
#                    "grup": ["muhasebe","muhendislik",
#                             "muhendislik","ik"]})
# df1

# %% [raw]
# df2 = pd.DataFrame({"calisanlar": ["ayse", "ali","veli","fatma"],
#                    "ilk giris": [2010,2009,2014,2019]})
# df2

# %% [raw]
# pd.merge(df1,df2)
#
# #degiskenlere gore birlestirme yapar ve kednisi anlar
# #eger degiskeni belirtmek istersek argüman vermeliyiz

# %% [raw]
# pd.merge(df1,df2,
#          on = "calisanlar")
#
# #birlestirilmesi istenen degiskeni "on" argümanı ile belirttik

# %% [raw]
# #many to one birlestirme
# df3 = pd.merge(df1,df2)
# df3

# %% [raw]
# df4 = pd.DataFrame({"grup": ["muhasebe", "muhendislik","ik"],
#                   "mudur": ["caner", "mustafa", "berkcan"]})
# df4

# %% [raw]
# pd.merge(df3,df4)

# %% [raw]
# #many to many birlestirme
# df5 = pd.DataFrame({"grup": ["muhasebe", "muhasebe",
#                              "muhendislik", "muhendislik",
#                             "ik", "ik"],
#                    "yetenekler": ["matematik", "excel",
#                                   "kodlama","linux",
#                                   "excel","yonetim"]})
# df5

# %% [raw]
# pd.merge(df1,df5)

# %% [raw]
# **TOPLULASTIRMA VE GRUPLAMA (AGGREGATION & REGROUPING)**

# %% [raw]
# basit toplulastirma fonksiyonlari:
#     count()
#     first()
#     last()
#     mean()
#     median()
#     min()
#     max()
#     std()
#     var()
#     sum()

# %% [raw]
# import seaborn as sns
# #seaborn lib yüklendi

# %% [raw]
# df = sns.load_dataset("planets")
# df.head()

# %% [raw]
# df.shape

# %% [raw]
# df.mean()

# %% [raw]
# df["mass"].mean()

# %% [raw]
# df["mass"].count()

# %% [raw]
# df["mass"].sum()

# %% [raw]
# df["mass"].std()

# %% [raw]
# df["mass"].var()

# %% [raw]
# df.describe() #yukarıdaki fonksiyonlari df seklinde gosterir

# %% [raw]
# df.describe().T #transpozunu aldı

# %% [raw]
# #veri setinin icinde eksik degerler olması halinde
#
# df.dropna().describe().T

# %% [raw]
# **GRUPLAMA İSLEMLERİ**

# %% [raw]
# import numpy as np
# import pandas as pd
# import seaborn as sns
# df = pd.DataFrame({"gruplar": ["A","B","C","A","B","C"],
#                   "veri": [10,11,52,23,43,55]},
#                    columns = ["gruplar","veri"])
# df

# %% [raw]
# df.groupby("gruplar")

# %% [raw]
# df.groupby("gruplar").mean()
#
# #groupby ile bir araya getirdik sonrasında toplama islem yaptik

# %% [raw]
# df.groupby("gruplar").sum()

# %% [raw]
# df = sns.load_dataset("planets")
# df

# %% [raw]
# df.head()

# %% [raw]
# df.groupby("method")["orbital_period"].mean()

# %% [raw]
# df.groupby("method")["mass"].mean()

# %% [raw]
# df.groupby("method")["orbital_period"].describe()

# %% [raw]
# **İleri Toplulastırma Islemleri
# (aggregate, filter, transform, apply)**

# %% [raw]
# import pandas as pd
# import numpy as np
# df = pd.DataFrame({"gruplar": ["A","B","C","A","B","C"],
#                   "degisken1": [10,11,52,23,43,55],
#                   "degisken2": [100,253,333,262,111,969]},
#                    columns = ["gruplar","degisken1",
#                               "degisken2"])
# df

# %% [raw]
# #aggregate: ilgili veriyi cogul sartlara gore toplulastırma

# %% [raw]
# df.groupby("gruplar").mean()

# %% [raw]
# df.groupby("gruplar").aggregate(["max", "min", np.median])

# %% [raw]
# df.groupby("gruplar").aggregate({"degisken1": sum,
#                                  "degisken2": "std"})

# %% [raw]
# #filter: kendi kosullarimizi fonk ile dfte sorgulamaya yarar

# %% [raw]
# df = pd.DataFrame({"gruplar": ["A","B","C","A","B","C"],
#                   "degisken1": [10,23,33,22,11,99],
#                   "degisken2": [100,253,333,262,111,969]},
#                    columns = ["gruplar","degisken1",
#                               "degisken2"])
# df

# %% [raw]
# def filter_func(x):
#     return x["degisken1"].std() > 45

# %% [raw]
# df.groupby("gruplar").filter(filter_func)

# %% [raw]
# df.groupby("gruplar").std()

# %% [raw]
# #transform:

# %% [raw]
# df = pd.DataFrame({"gruplar": ["A","B","C","A","B","C"],
#                   "degisken1": [10,23,33,22,11,99],
#                   "degisken2": [100,253,333,262,111,969]},
#                    columns = ["gruplar","degisken1",
#                               "degisken2"])
# df

# %% [markdown]
# import pandas_datareader as web
# import pandas as pd
# import datetime as dt

# %% [markdown]
# crypto = "BTC"
# currency = "USD"
#
# start = dt.datetime(2022,3,3)
# end = dt.datetime.now()
#
# data = web.DataReader(f"{crypto}-{currency}",
#                       "yahoo", start, end)

# %% [markdown]
# data["Close"].values.reshape(95,1)

# %%
import requests
from bs4 import BeautifulSoup
from requests_html import HTMLSession

session = HTMLSession()

# %%
url = 'https://www.investing.com/equities/nike'

page = session.get(url)

soup = BeautifulSoup(page.content, 'html.parser')

company = soup.find('h1', {'class': 'text-2xl font-semibold instrument-header_title__GTWDv mobile:mb-2'}).text
print(company)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [51], in <cell line: 7>()
#       3 page = session.get(url)
#       5 soup = BeautifulSoup(page.content, 'html.parser')
# ----> 7 company = soup.find('h1', {'class': 'text-2xl font-semibold instrument-header_title__GTWDv mobile:mb-2'}).text
#       8 print(company)
#
# AttributeError: 'NoneType' object has no attribute 'text'
